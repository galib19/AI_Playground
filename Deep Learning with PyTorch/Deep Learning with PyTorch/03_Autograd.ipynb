# %%
import torch

# %%
x = torch.randn(3, requires_grad=True)
x
# Out:
# tensor([ 0.4760, -1.6258,  1.6002], requires_grad=True)

# %%
y = x+2
y
# Out:
# tensor([2.4760, 0.3742, 3.6002], grad_fn=<AddBackward0>)

# %%
z = y*y*2
z
# Out:
# tensor([12.2613,  0.2800, 25.9225], grad_fn=<MulBackward0>)

# %%
z=z.mean()
z
# Out:
# tensor(12.8213, grad_fn=<MeanBackward0>)

# %%
z.backward() #dz/dx
x.grad
# Out:
# tensor([3.3013, 0.4989, 4.8002])

# %%
z2 = y*y*2
# z2.backward() #when z2 is not scalar, backward() will not work
#because in the background it is a vector jacobian product
#to make it working...
v = torch.tensor([0.1, 1.0, 0.001], dtype = torch.float32)
z2.backward(v)
x.grad
# Out:
# tensor([5.2822, 3.4922, 4.8290])

# %%
#how to stop gradient tracking off
# 3 ways:
# x.requires_grad_(False)
# x.detach()
# with torch.no_grad():

x.requires_grad_(False)
print(x)
# Out:
# tensor([ 0.4760, -1.6258,  1.6002])

# %%
x = torch.randn(3, requires_grad=True)
y = x.detach()
x, y
# Out:
# (tensor([ 1.0053, -0.1219, -2.4166], requires_grad=True),
#  tensor([ 1.0053, -0.1219, -2.4166]))

# %%
with torch.no_grad():
  y = x+2
  print(y)
print(y), print(x)
# Out:
# tensor([ 3.0053,  1.8781, -0.4166])
# tensor([ 3.0053,  1.8781, -0.4166])
# tensor([ 1.0053, -0.1219, -2.4166], requires_grad=True)
# (None, None)

# %%
weights = torch.ones(4, requires_grad=True)
for epoch in range(3):
  model_output = (weights*3).sum()
  model_output.backward()
  print(weights.grad)
  #gradients are wrong
# Out:
# tensor([3., 3., 3., 3.])
# tensor([6., 6., 6., 6.])
# tensor([9., 9., 9., 9.])

# %%
weights = torch.ones(4, requires_grad=True)
for epoch in range(3):
  model_output = (weights*3).sum()
  model_output.backward()
  print(weights.grad)
  weights.grad.zero_()
# Out:
# tensor([3., 3., 3., 3.])
# tensor([3., 3., 3., 3.])
# tensor([3., 3., 3., 3.])

# %%
weights = torch.ones(4, requires_grad=True)

optimizer = torch.optim.SGD(weights, lr = 0.01)
optimizer.step()
optimizer.zero_grad() # will do the same as previous cell
